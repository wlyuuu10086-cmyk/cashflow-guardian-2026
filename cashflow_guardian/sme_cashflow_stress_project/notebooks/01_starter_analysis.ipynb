# %% [markdown]
# # SME Cash Flow Starter Notebook

# %%
import duckdb, pandas as pd
con = duckdb.connect("../data/sme_cashflow_stress.duckdb")
con.sql("SELECT * FROM vw_table_row_counts ORDER BY row_count DESC").df()
